# %% [markdown]
# <a href="https://colab.research.google.com/github/Junse0/class2021Fall/blob/main/20211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
amp = 1; sr = 10000; phase = 0

G4 = 392.00
B4 = 493.88
D5 = 587.33
F4 = 369.99
E4 = 329.63 
E5 = 659.25
A4 = 440.00
D4 = 293.66

# %%
# Faded

notes=[G4,0,G4,0,G4,0,B4,0,E5,0,E5,0,E5,0,D5,0,B4,0,B4,0,B4,0,B4,0,F4,0,F4,0,F4,0,E4,\
       G4,G4,E4,G4,E4,G4,A4,B4,G4,G4,D4,B4,0,\
       G4,G4,G4,F4,F4,F4,E4,G4]
durs=[0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,0.6,0.01,1.2,\
      0.3,0.3,0.3,0.3,0.3,0.3,0.3,0.6,0.3,0.3,0.3,1.2,0.01,\
      0.3,0.3,0.3,0.6,0.3,0.3,0.3,0.6]

# %%
s_all = np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th= phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
